# %%
import openfst_python as fst
compiler = fst.Compiler()

# %% [markdown]
# ## ASCII kodovi
#
# 0	48
# 1	49
# 2	50
# 3	51
# 4	52
# 5	53
# 6	54
# 7	55
# 8	56
# 9	57
#
# a	97
# b	98
# c	99
# d	100
# e	101
# f	102
# g	103
# h	104
# i	105
# j	106
# k	107
# l	108
# m	109
# n	110
# o	111
# p	112
# q	113
# r	114
# s	115
# t	116
# u	117
# v	118
# w	119
# x	120
# y	121
# z	122

# %% [markdown]
# Jednoznamenkasti brojevi:

# %%
f = fst.Fst()
p = f.add_state()
s0 = f.add_state()
s1 = f.add_state()
s2 = f.add_state()
s3 = f.add_state()
s4 = f.add_state()
s5 = f.add_state()
s6 = f.add_state()
s7 = f.add_state()
s8 = f.add_state()
s9 = f.add_state()

f.set_start(p)
f.add_arc(p, fst.Arc(0,0,0,s0))
f.add_arc(p, fst.Arc(1,1,0,s1))
f.add_arc(p, fst.Arc(2,2,0,s2))
f.add_arc(p, fst.Arc(3,3,0,s3))
f.add_arc(p, fst.Arc(4,4,0,s4))
f.add_arc(p, fst.Arc(5,5,0,s5))
f.add_arc(p, fst.Arc(6,6,0,s6))
f.add_arc(p, fst.Arc(7,7,0,s7))
f.add_arc(p, fst.Arc(8,8,0,s8))
f.add_arc(p, fst.Arc(9,9,0,s9))

## nula = 110 117 108 97
n_nula = f.add_state()
u_nula = f.add_state()
l_nula = f.add_state()
a_nula = f.add_state()
f.add_arc(s0, fst.Arc(0,110,0,n_nula))
f.add_arc(n_nula, fst.Arc(110,117,0,u_nula))
f.add_arc(u_nula, fst.Arc(117,108,0,l_nula))
f.add_arc(l_nula, fst.Arc(108,97,0,a_nula))
f.set_final(a_nula,0)

## jedan =  106 101 100 97 110
j = f.add_state()
e = f.add_state()
d = f.add_state()
a = f.add_state()
n = f.add_state()
f.add_arc(s1, fst.Arc(1,106,0,j))
f.add_arc(j, fst.Arc(106,101,0,e))
f.add_arc(e, fst.Arc(101,100,0,d))
f.add_arc(d, fst.Arc(100,97,0,a))
f.add_arc(a, fst.Arc(97,110,0,n))
f.set_final(n,0)

## dva = 100 118 97
d_Dva= f.add_state()
v_Dva = f.add_state()
a_Dva = f.add_state()
f.add_arc(s2, fst.Arc(2,100,0,d_Dva))
f.add_arc(d_Dva, fst.Arc(100,118,0,v_Dva))
f.add_arc(v_Dva, fst.Arc(118,97,0,a_Dva))
f.set_final(a_Dva,0)


## tri = 116 114 105
t_Tri = f.add_state()
r_Tri = f.add_state()
i_Tri = f.add_state()
f.add_arc(s3, fst.Arc(3,116,0,t_Tri))
f.add_arc(t_Tri, fst.Arc(116,114,0,r_Tri))
f.add_arc(r_Tri, fst.Arc(114,105,0,i_Tri))
f.set_final(i_Tri,0)


## cetiri = 99 101 116 105 114 105
c4 = f.add_state()
e4 = f.add_state()
t4 = f.add_state()
i4 = f.add_state()
r4 = f.add_state()
di4 = f.add_state()
f.set_final(di4,0)

f.add_arc(s4, fst.Arc(4,99,0,c4))
f.add_arc(c4, fst.Arc(99,101,0,e4))
f.add_arc(e4, fst.Arc(101,116,0,t4))
f.add_arc(t4, fst.Arc(116,105,0,i4))
f.add_arc(i4, fst.Arc(105,114,0,r4))
f.add_arc(r4, fst.Arc(114,105,0,di4))



## pet = 112 101 116
p5 = f.add_state()
e5 = f.add_state()
t5 = f.add_state()
f.add_arc(s5, fst.Arc(5,112,0,p5))
f.add_arc(p5, fst.Arc(112,101,0,e5))
f.add_arc(e5, fst.Arc(101,116,0,t5))
f.set_final(t5,0)


## sest = 115 101 115 116
s_6 = f.add_state()
e6 = f.add_state()
ds6 = f.add_state()
t6 = f.add_state()

f.add_arc(s6, fst.Arc(6,115,0,s_6))
f.add_arc(s_6, fst.Arc(115,101,0,e6))
f.add_arc(e6, fst.Arc(101,115,0,ds6))
f.add_arc(ds6, fst.Arc(115,116,0,t6))
f.set_final(t6,0)



## sedam = 115 101 100 97 109
s_7 = f.add_state()
e7 = f.add_state()
d7 = f.add_state()
a7 = f.add_state()
m7 = f.add_state()

f.add_arc(s7, fst.Arc(7,115,0,s_7))
f.add_arc(s_7, fst.Arc(115,101,0,e7))
f.add_arc(e7, fst.Arc(101,100,0,d7))
f.add_arc(d7, fst.Arc(100,97,0,a7))
f.add_arc(a7, fst.Arc(97,109,0,m7))
f.set_final(m7,0)


## osam = 111 115 97 109
o8 = f.add_state()
s_8 = f.add_state()
a8 = f.add_state()
m8 = f.add_state()

f.add_arc(s8, fst.Arc(8,111,0,o8))
f.add_arc(o8, fst.Arc(111,115,0,s_8))
f.add_arc(s_8, fst.Arc(115,97,0,a8))
f.add_arc(a8, fst.Arc(97,109,0,m8))
f.set_final(m8,0)


## devet = 100 101 118 101 116
d9 = f.add_state()
e9 = f.add_state()
v9 = f.add_state()
de9 = f.add_state()
t9 = f.add_state()

f.add_arc(s9, fst.Arc(9,100,0,d9))
f.add_arc(d9, fst.Arc(100,101,0,e9))
f.add_arc(e9, fst.Arc(101,118,0,v9))
f.add_arc(v9, fst.Arc(118,101,0,de9))
f.add_arc(de9, fst.Arc(101,116,0,t9))
f.set_final(t9,0)
# Out:
# <vector Fst at 0x7fba44550a70>
